# %% [markdown]
# # Graph cut method for bloodcells counting
#
# A ot of thanks for contribution to Paweł :)

# %% [markdown]
# Example 1: PNG file with reddish background - adaptive approach for flow treshold.

# %%
from PIL import Image
import numpy as np
import networkx as nx
from matplotlib import pyplot as plt
from scipy.stats import norm
from networkx.algorithms.flow import edmonds_karp

# %% [markdown]
# Necessary functions for pipeline:

# %%
def get_distribution(image):
    im_data = np.array(image.getchannel('G'),dtype='int64')
    im_data = im_data.reshape(im_data.shape[0] * im_data.shape[1], 1)
    mu, std = norm.fit(im_data)
    return mu, std

def get_bitmap(R, threshold, dimx, dimy):
    bitmap = np.zeros((dimx, dimy))
    for i in range(dimx):
        for j in range(dimy):
            if R['s'][(i,j)]['flow'] > threshold:
                bitmap[i][j] = 1
    return bitmap

def create_graph(arr, mu, std, k, s):
    G = nx.DiGraph()
    for i in range(arr.shape[0]):
        for j in range(arr.shape[1]):
            G.add_node((i,j))
    G.add_node('s')
    G.add_node('t')
    for y in range(arr.shape[1]):
        for x in range(arr.shape[0]):
            if x > 0:
                G.add_edge((x,y),(x-1,y),capacity=(k * np.exp((abs(arr[x,y] - arr[x-1,y])) ** 2 / s)))
                G.add_edge((x-1,y),(x,y),capacity=(k * np.exp((abs(arr[x,y] - arr[x-1,y])) ** 2 / s)))
            if y > 0:
                G.add_edge((x,y),(x,y-1),capacity=(k * np.exp((abs(arr[x,y] - arr[x,y-1])) ** 2 / s)))
                G.add_edge((x,y-1),(x,y),capacity=(k * np.exp((abs(arr[x,y] - arr[x,y-1])) ** 2 / s)))
            G.add_edge((x,y),'t',capacity=(1 - norm(mu, std).pdf(arr[x,y])))
            G.add_edge('s',(x,y),capacity=(norm(mu, std).pdf(arr[x,y])))
    return G

# %% [markdown]
# Pipeline:

# %%
def image_processing_pipeline(image):
    
    # image is an opened picture
    image_arr = np.array(image,dtype='int64')
    
    width, height, depth = image_arr.shape
    
    result_image = np.zeros((width, height, depth))
    
    # find a fitting distribution for background
    mu, std = get_distribution(image)
    
    w_coords = list(range(0, width, 32))
    h_coords = list(range(0, height, 32))
    
    if w_coords[-1] != width - 1:
        w_coords.append(width - 1)
    if h_coords[-1] != height - 1:
        h_coords.append(height - 1)

    for d in range(depth):
        # we split the image into 32x32 subimages
        for w in range(len(w_coords) - 1): # not considering last element
            for h in range(len(h_coords) - 1):
                arr = image_arr[w_coords[w]:w_coords[w+1], h_coords[h]:h_coords[h+1], d]
                
                G = create_graph(arr, mu, std, 0.00025, 20)
                
                R = edmonds_karp(G, 's', 't')
                
                print('Current flow:', R.graph['flow_value'], end=' ')
                
                # compute possible treshold for current digraph
                mean = R.graph['flow_value'] / len(G.nodes())
                
                dimx = w_coords[w+1] - w_coords[w]
                dimy = h_coords[h+1] - h_coords[h]
                bitmap = get_bitmap(R, mean, dimx, dimy)
                
                arr2 = arr * bitmap
                
                result_image[w_coords[w]:w_coords[w+1], h_coords[h]:h_coords[h+1], d] = arr2
                
                print('Slice {}:{},{}:{},{} done!'.format(w_coords[w], w_coords[w+1], h_coords[h], h_coords[h+1], d))

    return result_image

# %%
image = Image.open('red_blood_cells.png').resize((200,200))
result = image_processing_pipeline(image)
# Out:
# Current flow: 5.887598670454321 Slice 0:32,0:32,0 done!
# Current flow: 5.350813595274323 Slice 0:32,32:64,0 done!
# Current flow: 5.394869402492576 Slice 0:32,64:96,0 done!
# Current flow: 5.244505776147061 Slice 0:32,96:128,0 done!
# Current flow: 5.646137907412559 Slice 0:32,128:160,0 done!
# Current flow: 5.603016572383532 Slice 0:32,160:192,0 done!
# Current flow: 1.2734878367109328 Slice 0:32,192:199,0 done!
# Current flow: 5.435917638008077 Slice 32:64,0:32,0 done!
# Current flow: 5.388717434354796 Slice 32:64,32:64,0 done!
# Current flow: 5.682796731546815 Slice 32:64,64:96,0 done!
# Current flow: 5.348936218435485 Slice 32:64,96:128,0 done!
# Current flow: 5.396138587056994 Slice 32:64,128:160,0 done!
# Current flow: 5.379921828370478 Slice 32:64,160:192,0 done!
# Current flow: 1.2411783887955037 Slice 32:64,192:199,0 done!
# Current flow: 5.747053990626842 Slice 64:96,0:32,0 done!
# Current flow: 5.708546014544741 Slice 64:96,32:64,0 done!
# Current flow: 5.648176248626391 Slice 64:96,64:96,0 done!
# Current flow: 5.620398837043415 Slice 64:96,96:128,0 done!
# Current flow: 5.508705084096951 Slice 64:96,128:160,0 done!
# Current flow: 5.7479596274286635 Slice 64:96,160:192,0 done!
# Current flow: 1.2243525845079068 Slice 64:96,192:199,0 done!
# Current flow: 5.621361425794604 Slice 96:128,0:32,0 done!
# Current flow: 5.566925046423294 Slice 96:128,32:64,0 done!
# Current flow: 5.7944105073094 Slice 96:128,64:96,0 done!
# Current flow: 5.895372327117325 Slice 96:128,96:128,0 done!
# Current flow: 5.71395153082385 Slice 96:128,128:160,0 done!
# Current flow: 5.729338474893014 Slice 96:128,160:192,0 done!
# Current flow: 1.2178174191294264 Slice 96:128,192:199,0 done!
# Current flow: 5.7359862222400855 Slice 128:160,0:32,0 done!
# Current flow: 5.465744062105775 Slice 128:160,32:64,0 done!
# Current flow: 5.980060142096956 Slice 128:160,64:96,0 done!
# Current flow: 5.781982155647352 Slice 128:160,96:128,0 done!
# Current flow: 5.766234874313272 Slice 128:160,128:160,0 done!
# Current flow: 5.769825126152068 Slice 128:160,160:192,0 done!
# Current flow: 1.3267022130187587 Slice 128:160,192:199,0 done!
# Current flow: 5.469596698078313 Slice 160:192,0:32,0 done!
# Current flow: 5.477671337939949 Slice 160:192,32:64,0 done!
# Current flow: 5.901561153375333 Slice 160:192,64:96,0 done!
# Current flow: 5.808017422647151 Slice 160:192,96:128,0 done!
# Current flow: 5.751855334218453 Slice 160:192,128:160,0 done!
# Current flow: 5.59256713636677 Slice 160:192,160:192,0 done!
# Current flow: 1.1606729264827529 Slice 160:192,192:199,0 done!
# Current flow: 1.1781645094051199 Slice 192:199,0:32,0 done!
# Current flow: 1.2358255873304715 Slice 192:199,32:64,0 done!
# Current flow: 1.2081287368012028 Slice 192:199,64:96,0 done!
# Current flow: 1.288208375338771 Slice 192:199,96:128,0 done!
# Current flow: 1.2562533609845667 Slice 192:199,128:160,0 done!
# Current flow: 1.2276353188255187 Slice 192:199,160:192,0 done!
# Current flow: 0.29934140799540865 Slice 192:199,192:199,0 done!
# Current flow: 5.766180678272985 Slice 0:32,0:32,1 done!
# Current flow: 6.176742360312881 Slice 0:32,32:64,1 done!
# Current flow: 6.176979715235612 Slice 0:32,64:96,1 done!
# Current flow: 6.231429450502981 Slice 0:32,96:128,1 done!
# Current flow: 6.057486357547304 Slice 0:32,128:160,1 done!
# Current flow: 6.052569611735385 Slice 0:32,160:192,1 done!
# Current flow: 1.2369580225366215 Slice 0:32,192:199,1 done!
# Current flow: 6.143601719014453 Slice 32:64,0:32,1 done!
# Current flow: 5.9867989125502605 Slice 32:64,32:64,1 done!
# Current flow: 6.063334490726033 Slice 32:64,64:96,1 done!
# Current flow: 6.138612880095214 Slice 32:64,96:128,1 done!
# Current flow: 6.224520603549117 Slice 32:64,128:160,1 done!
# Current flow: 6.098508566578023 Slice 32:64,160:192,1 done!
# Current flow: 1.3322110180346773 Slice 32:64,192:199,1 done!
# Current flow: 5.706600024319093 Slice 64:96,0:32,1 done!
# Current flow: 5.893635890851008 Slice 64:96,32:64,1 done!
# Current flow: 5.972183680449932 Slice 64:96,64:96,1 done!
# Current flow: 6.039323463137785 Slice 64:96,96:128,1 done!
# Current flow: 5.94739949776205 Slice 64:96,128:160,1 done!
# Current flow: 5.794286998553622 Slice 64:96,160:192,1 done!
# Current flow: 1.2720423667120333 Slice 64:96,192:199,1 done!
# Current flow: 5.8338785771555965 Slice 96:128,0:32,1 done!
# Current flow: 5.8481817493833494 Slice 96:128,32:64,1 done!
# Current flow: 5.25938923730216 Slice 96:128,64:96,1 done!
# Current flow: 5.48754112105912 Slice 96:128,96:128,1 done!
# Current flow: 5.93294798361147 Slice 96:128,128:160,1 done!
# Current flow: 5.797481009078365 Slice 96:128,160:192,1 done!
# Current flow: 1.3007789990479517 Slice 96:128,192:199,1 done!
# Current flow: 5.66813353980507 Slice 128:160,0:32,1 done!
# Current flow: 5.953507716483482 Slice 128:160,32:64,1 done!
# Current flow: 5.5333377889463815 Slice 128:160,64:96,1 done!
# Current flow: 5.706479145105577 Slice 128:160,96:128,1 done!
# Current flow: 5.712965263175971 Slice 128:160,128:160,1 done!
# Current flow: 5.772559428360246 Slice 128:160,160:192,1 done!
# Current flow: 1.2036668792280167 Slice 128:160,192:199,1 done!
# Current flow: 5.855519010543415 Slice 160:192,0:32,1 done!
# Current flow: 5.874103884200503 Slice 160:192,32:64,1 done!
# Current flow: 5.447912131704678 Slice 160:192,64:96,1 done!
# Current flow: 5.692436987411314 Slice 160:192,96:128,1 done!
# Current flow: 5.747602217942563 Slice 160:192,128:160,1 done!
# Current flow: 5.870850912510249 Slice 160:192,160:192,1 done!
# Current flow: 1.2728065956393448 Slice 160:192,192:199,1 done!
# Current flow: 1.2694557225175158 Slice 192:199,0:32,1 done!
# Current flow: 1.2375534707349227 Slice 192:199,32:64,1 done!
# Current flow: 1.240734742770257 Slice 192:199,64:96,1 done!
# Current flow: 1.2356704893115142 Slice 192:199,96:128,1 done!
# Current flow: 1.2602204898237326 Slice 192:199,128:160,1 done!
# Current flow: 1.302823717615629 Slice 192:199,160:192,1 done!
# Current flow: 0.26285617576262615 Slice 192:199,192:199,1 done!
# Current flow: 6.173553500446561 Slice 0:32,0:32,2 done!
# Current flow: 6.025918409232405 Slice 0:32,32:64,2 done!
# Current flow: 6.096948175781552 Slice 0:32,64:96,2 done!
# Current flow: 5.966675881173873 Slice 0:32,96:128,2 done!
# Current flow: 6.291273209112321 Slice 0:32,128:160,2 done!
# Current flow: 6.328645185088582 Slice 0:32,160:192,2 done!
# Current flow: 1.3216526134371316 Slice 0:32,192:199,2 done!
# Current flow: 6.096945066319495 Slice 32:64,0:32,2 done!
# Current flow: 5.824704362850852 Slice 32:64,32:64,2 done!
# Current flow: 6.3193620303806295 Slice 32:64,64:96,2 done!
# Current flow: 5.960537458968371 Slice 32:64,96:128,2 done!
# Current flow: 6.161613354341971 Slice 32:64,128:160,2 done!
# Current flow: 6.004503032396025 Slice 32:64,160:192,2 done!
# Current flow: 1.4418653242889248 Slice 32:64,192:199,2 done!
# Current flow: 5.966933677494552 Slice 64:96,0:32,2 done!
# Current flow: 6.143441961197543 Slice 64:96,32:64,2 done!
# Current flow: 6.104539015564703 Slice 64:96,64:96,2 done!
# Current flow: 6.255974939342203 Slice 64:96,96:128,2 done!
# Current flow: 5.962353308623956 Slice 64:96,128:160,2 done!
# Current flow: 6.144609634717705 Slice 64:96,160:192,2 done!
# Current flow: 1.2921482189362625 Slice 64:96,192:199,2 done!
# Current flow: 5.992283683544494 Slice 96:128,0:32,2 done!
# Current flow: 5.920639808384561 Slice 96:128,32:64,2 done!
# Current flow: 6.105953354977382 Slice 96:128,64:96,2 done!
# Current flow: 6.341070571064817 Slice 96:128,96:128,2 done!
# Current flow: 6.313381220645175 Slice 96:128,128:160,2 done!
# Current flow: 6.145430946944335 Slice 96:128,160:192,2 done!
# Current flow: 1.3222079606586166 Slice 96:128,192:199,2 done!
# Current flow: 6.000755832548884 Slice 128:160,0:32,2 done!
# Current flow: 5.949816939894181 Slice 128:160,32:64,2 done!
# Current flow: 6.1198023969704645 Slice 128:160,64:96,2 done!
# Current flow: 6.033919108671706 Slice 128:160,96:128,2 done!
# Current flow: 6.0677007354424 Slice 128:160,128:160,2 done!
# Current flow: 6.1543462760841425 Slice 128:160,160:192,2 done!
# Current flow: 1.3574511147920267 Slice 128:160,192:199,2 done!
# Current flow: 5.870750145402263 Slice 160:192,0:32,2 done!
# Current flow: 5.888411257239337 Slice 160:192,32:64,2 done!
# Current flow: 5.980574936122848 Slice 160:192,64:96,2 done!
# Current flow: 6.102898562674532 Slice 160:192,96:128,2 done!
# Current flow: 6.119910667178626 Slice 160:192,128:160,2 done!
# Current flow: 6.120272427828382 Slice 160:192,160:192,2 done!
# Current flow: 1.2035740039734106 Slice 160:192,192:199,2 done!
# Current flow: 1.21724718101853 Slice 192:199,0:32,2 done!
# Current flow: 1.3108813609795056 Slice 192:199,32:64,2 done!
# Current flow: 1.2783342355347072 Slice 192:199,64:96,2 done!
# Current flow: 1.3568044266515846 Slice 192:199,96:128,2 done!
# Current flow: 1.3161013435890179 Slice 192:199,128:160,2 done!
# Current flow: 1.3358152265086607 Slice 192:199,160:192,2 done!
# Current flow: 0.28829807420538495 Slice 192:199,192:199,2 done!
# Current flow: 4.098558952327067 Slice 0:32,0:32,3 done!
# Current flow: 4.098558952327067 Slice 0:32,32:64,3 done!
# Current flow: 4.098558952327067 Slice 0:32,64:96,3 done!
# Current flow: 4.098558952327067 Slice 0:32,96:128,3 done!
# Current flow: 4.098558952327067 Slice 0:32,128:160,3 done!
# Current flow: 4.098558952327067 Slice 0:32,160:192,3 done!
# Current flow: 0.8965597708215642 Slice 0:32,192:199,3 done!
# Current flow: 4.098558952327067 Slice 32:64,0:32,3 done!
# Current flow: 4.098558952327067 Slice 32:64,32:64,3 done!
# Current flow: 4.098558952327067 Slice 32:64,64:96,3 done!
# Current flow: 4.098558952327067 Slice 32:64,96:128,3 done!
# Current flow: 4.098558952327067 Slice 32:64,128:160,3 done!
# Current flow: 4.098558952327067 Slice 32:64,160:192,3 done!
# Current flow: 0.8965597708215642 Slice 32:64,192:199,3 done!
# Current flow: 4.098558952327067 Slice 64:96,0:32,3 done!
# Current flow: 4.098558952327067 Slice 64:96,32:64,3 done!
# Current flow: 4.098558952327067 Slice 64:96,64:96,3 done!
# Current flow: 4.098558952327067 Slice 64:96,96:128,3 done!
# Current flow: 4.098558952327067 Slice 64:96,128:160,3 done!
# Current flow: 4.098558952327067 Slice 64:96,160:192,3 done!
# Current flow: 0.8965597708215642 Slice 64:96,192:199,3 done!
# Current flow: 4.098558952327067 Slice 96:128,0:32,3 done!
# Current flow: 4.098558952327067 Slice 96:128,32:64,3 done!
# Current flow: 4.098558952327067 Slice 96:128,64:96,3 done!
# Current flow: 4.098558952327067 Slice 96:128,96:128,3 done!
# Current flow: 4.098558952327067 Slice 96:128,128:160,3 done!
# Current flow: 4.098558952327067 Slice 96:128,160:192,3 done!
# Current flow: 0.8965597708215642 Slice 96:128,192:199,3 done!
# Current flow: 4.098558952327067 Slice 128:160,0:32,3 done!
# Current flow: 4.098558952327067 Slice 128:160,32:64,3 done!
# Current flow: 4.098558952327067 Slice 128:160,64:96,3 done!
# Current flow: 4.098558952327067 Slice 128:160,96:128,3 done!
# Current flow: 4.098558952327067 Slice 128:160,128:160,3 done!
# Current flow: 4.098558952327067 Slice 128:160,160:192,3 done!
# Current flow: 0.8965597708215642 Slice 128:160,192:199,3 done!
# Current flow: 4.098558952327067 Slice 160:192,0:32,3 done!
# Current flow: 4.098558952327067 Slice 160:192,32:64,3 done!
# Current flow: 4.098558952327067 Slice 160:192,64:96,3 done!
# Current flow: 4.098558952327067 Slice 160:192,96:128,3 done!
# Current flow: 4.098558952327067 Slice 160:192,128:160,3 done!
# Current flow: 4.098558952327067 Slice 160:192,160:192,3 done!
# Current flow: 0.8965597708215642 Slice 160:192,192:199,3 done!
# Current flow: 0.8965597708215642 Slice 192:199,0:32,3 done!
# Current flow: 0.8965597708215642 Slice 192:199,32:64,3 done!
# Current flow: 0.8965597708215642 Slice 192:199,64:96,3 done!
# Current flow: 0.8965597708215642 Slice 192:199,96:128,3 done!
# Current flow: 0.8965597708215642 Slice 192:199,128:160,3 done!
# Current flow: 0.8965597708215642 Slice 192:199,160:192,3 done!
# Current flow: 0.1961224498672169 Slice 192:199,192:199,3 done!

# %%
plt.imshow(result)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
